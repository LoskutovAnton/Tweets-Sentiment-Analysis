# %% [markdown]
# ## Getting new tweets

# %%
from tweepy import StreamListener
from tweepy import Stream
import tweepy

access_token = "713106538-mp6L2FjeZBC7IGkBjxGd20VqSGnCMe32fITNjDHA"
access_token_secret = "Dw73yZFxCZHDgLZwTiMc4o93vLbHN1CCr2mcr1LSY5WC4"
consumer_key = "9oPFg8iUjWOrLvZ13C8FoXX5a"
consumer_secret = "jliZF603JchC2IHHCEWxdtCSQPN0US8phBxMmP7sredb7VJmHH"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

user = api.get_user('@wylsacom')

print(user.screen_name, user.followers_count)
# Out:
# (u'wylsacom', 1204789)

# %%
import re
def prepare_text(text):
    text = text.lower().strip()
    text = re.sub(r'@\S+', '', text) # delete @user_name
    text = re.sub(r'#\W+', '', text) # delete #hashtag
    text = re.sub(r'http\S+', ' ', text)
    text = re.sub(r'[o_, O_, dd, dddd, ddd, 0-9, \:, \(, \), \!, \-, \;, \?, rt, \#]+', ' ', text) # delete smiles
    return text

# %%
def get_user_recent_tweets(username, count):
    tweets = []
    try:
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_token_secret)
        api = tweepy.API(auth)
    except Exception:
        print("Auth error")
    try:
        user = api.get_user(username)
        tweets = [prepare_text(tweet.text) for tweet in user.timeline(count=count)]
    except Exception:
        print("Getting timeline error")
    print("Loaded %d tweets" % (len(tweets)))
    return tweets

# %%
user_tweets = get_user_recent_tweets('@wylsacom', 100)
# Out:
# Loaded 200 tweets

# %%
len(user_tweets)
# Out:
# 200

# %%
print '\n\n'.join(user_tweets)
# Out:
#  почему iph ne xc будет крут доступная версия iph ne x в ярких цветах
#
# как может выглядеть бюд…
#
# фото для тех кто считает что порще не идет зеленый.
#
# очень.
#
#  без шумодава
#
#  страдаю с
#
# подрезал у s ny новые наушники линейки. очень ок. большие прям даже мои любимые qc с пьедестала двигают а м…
#
#  эпизоды
#
# я вам радость принес.
#
#  как называется
#
#  еще раз после всей херни с посольством теперь заворачивают. я вот тоже отправил и потопа…
#
#  в питере открыли с декабря но чекай мест не было до февраля
#
#  вот как вся чехарда с сокращением консульского штата так нет
#
#  заполняешь s на сайте записываешься на собеседование приходишь с листком подтверждения даты и паспортом. все
#
#  ничо не надо показывать
#
# приговор улюкаеву лет строго режима. смешанные чувства. с одной стороны брал ли взятки бывший министр экономи…
#
#  внезапно появились даты но на продление. на первичное нет.
#
#  маршрутизатор
#
# а ну и второй раз прохожу собеседование на визу сша и второй раз при мне заворачивают людей с кипой бумажек «это в…
#
#  русское так и сказали
#
# зашел рядом с посольством сша в g man. блин в анахайме за счет blizza 🤘ходил в крутейший американский стейк ха…
#
#  помыться как раз а завтракать без вариантов да
#
#  ты не геймер если у тебя нет свитча
#
# получил америкаанскую визу. спросили а чо вы так часто летаете 😂
# ну подписал консула на wylsac m в итоге будет в курсе.
#
#  уважение 💪
#
#  ну еще я лег в
#
#  есть люди которым вот так ходить на работа по кайфу.
#
#  первые и последние
#
# первый ролик который y u ube подогнал мне под экран телефона. откройте с мобилки.
#
#
#  b в ai .
#
# встал в вышел из дома в утра. злой как скотина.
# лучшее что я сделал в лет ушел с работы где надо быт…
#
#  джойконы же менять можно.
#
#  топовый да.
#
# стоимость всех коинов доступных на рынке сейчас более $ . . . . нормальный такой пузырь.
#
#  я помню про это но по факту в оф. сц нам сказали что американцы не обслуживаются.
#
#  это проходит годам к . 👌
#
#  нука
#
# зацените какой у меня теперь swi ch. 👌
#
#  валя отдохни
#
#  в смысле я повторил не зависает.
#
#  херня чо.
#
# починил убитые iph ne plus и galaxy n e сколько стоит
#
# приятного просмотра
#
#  старый. ждем апдейт в сл. году
#
#  аналог ne flix
#
#  так купили сегодня
#
#  бгг чушь написал адскую.
#
# ладно f x. isney теперь принадлежит hulu. а у микки мауса заканчивается через два года контракт с ne flix. в общим…
#
# это к вопросу о дорогом imac p . большинству такая сеть нахрен не упала. а я смогу неистово экономить время.
#
#  ну найди такой же скриншот шутка с биткоином настолько на поверхности что ой
#
# построили на студии прототип сети на гбит/с. пока так по приколу. а в новой студии у нас будет ад сотона и уда…
#
#  wylsac m
#
# роскомназдор может решить пойти строго на север так то.
#
#  нет конечно зачем
#
#  ваще хз кто это
#
# так ну я собрал себе не стыдный imac p . даже меньше биткоина. 👌
#
#  да нет.
#
# глупость. imac p профессиональный инструмент. не для игры в pubg.
#
#  не так не очень
#
# так мне в реплаи пишут про рамки у imac. типа они широкие. да вообще похрен ау. в этот моноблок засунули такое же…
#
# черный imac p секс конечно.
#
# там fcpx обновился царски. добавили v e i ing a vance c l g a ing ну и h . это то что на первый взгляд в…
#
#  купил
#
#  это опечатка
#
#  не мее с мака стримить не надо
#
# imac p в россии в продаже от . рублей. 👌
#
# братцы а подскажите приложение для a v чтоб можно было фильмы скачитвать. есть такое в природе
#
#  дорого и еле такое.
#
#  как
#
#  в москве мегафон/йота
#
#  валера беги с билайна. голоса нет интернета нет. худший оператор.
#
#  как я сходил на новые "звездные войны"
#
# и вот теперь apple купит isney. отличная многоходовочка тим.
#
# ужасно скучная пресс конференция путина. «журналисты» с плакатами стыдные какие то. песков каклй то супер непрофесс…
#
#  чего купить
#
# пресс конференция путина забавная конечно но там новость покруче isney покупает таки f x за $ . . . . у…
#
#  когда готов впечатать в стену ещё один порш
#
#  вот такой цвет в итоге будет прост такого в игре нет.
#
#  ээ ни вижу связи
#
#  починили.
#
# вкорячить apple v в машину было лучшим решением.
#
#  не я взял на год
#
#  просто интересно это после чего такое решение
#
#  у меря опель ты о чем
#
#  ну не прям стремная
#
# vela симпатичней f pace конечно.
#
#  полный релиз
#
#
#  спасибо зайду
#
# apple вложила $ . . в дальнейшее развитие технологии поверхностно излучающего лазера с вертикальным резонато…
#
#  задействует в полный рост в субботу будет видос
#
# ээ… apple выпустила i s . . be a для разработчиков.
#
# на никольской монтируют дичь. но красиво.
#
# запустил xb x ne x k/ пришлось менять пк
#
# приятного просмотра.
#
#  ну это с картой
#
#
#
# почти жду когда обработается…
#
#  конкретно это p e a там выбирать не приходится.
#
#  конкретно в этом ролике да
#
#  в субботу
#
# рендерю ролик в к/ и страдаю. если бы не egpu была бы вообще труба а так чуть чуть осталось.
#
# внезапно.
#
#  нравится
#
#  когда наколдовал себе дьявольское количество просмотров айфона шестерки
#
# g gle и каста. вот это отлично не то что ревайнд всратый.
#
#
#  конечно поможет так то в сервис там точно скажут. но похоже на просто мертвый аккум и его замена исправит ситуацию.
#
# зато у меня много кристаллов и скоро будет свой замок.
#
# у меня просто мало денег понятно.
#
#  я пользуюсь банками
#
# это огорчает. было трансферов в год стало . я так и так не пользовался почему то но обидно.
#
# осады подъехали.
#
#  изучаем на парах
#
#  у разрабов pubg вместо рук сковородки
#
# вчера весь день что то жрал а сегодня опять хочется как это работает
#
#  h w ab u a li le ease...
#
#  это очень плохая херня ничего общего с нашим креслом не имеющая
#
#  ты так далек что ппц
#
# а еще восьмой эпизод зв я смотрел на новом проекторе s ny в к. я пытался но разницы и какой то особой чоткости с «обычным» не увидел.
#
# чувствую в себе суперсиллу дичайше спойлерить восьмой эпизод. но я же не сноук какой нибудь.
#
#  нет спойлеров
#
#  разоблачение теории заговора.
#
# посмотрел восьмой эпизод звездных войн. хотел бы быть говноедом сноубом а каламбурчик но это офигенный фильм. в…
#
# приехал к нам msi с двумя . злой как скотина. 👌
#
#  нее
#
#  не в смысле что ты на меня не подписан
#
#  а ну ты не местный. так то я угораю постоянно. 🙆‍♂️
#
# хотел как царь сходить в четверг на звездные войны в пафосный кинотеатр москва. но там клубная карта вот это всё. н…
#
#  блэд да я рофлю в каждом твите если ты этого не понимаешь то грустно что.
#
#  видно что ты не умеешь в сарказм
#
# комикс с неожиданным финалом который мы заслужили.
#
# то что алгоритм может подставить лицо любого человека в порно это победа конечно.
#
#
# не могу выйти из машины потому что заиграла лучшая песня вообще.
#
#  не б/у не хочу
#
# братцы задача собрать царский комп… за тыс. рублей. чтоб к/ вот это все. подсобите идеями
#
#  тем что в bc / было круче
#
#  lineage ev lu i n
#
#  подстава нейросеть на службе у порно
#
#  подросток запустил imessage на an i
#
# там информация про ba c mpany утекла. выход в и вьетнам.
# блэд до сих пор вспоминаю систему разрушений в b…
#
#  ага
#
# вточил дули на + . с попытки
#
# решил кардинально что то изменить в жизни и установил новую мелодию будильника.
#
#  ну кстати информацию можно брать прям со смартфона
#
# иду по большому черкасскому переулку. лужи гигантские в москве + / градуса. едет x притормозил красавчик. еде…
#
#
#
# народ предостерегаю вас от использования шараги в августе через них покупал тур в грецию по их косяку п…
#
#  почему
#
# в общем парни кому u us не достался берите vela . выглядит лучше.
#
#  в смысле в офиц. розницу как стоил так и стоит.
#
# lamb ghini u us квота на россию машин стоимость от . . рублей. все раскуплены. плохо живем. 🙆‍♂️
# сам…
#
#  чтоб можно было тыкнуть и соедить
#
#  не s inge
#
# жеребьевка началась. 🙆‍♂️
#
#  a familia face will be helping us u wi h he ucl aw ay...
#
#  так то прикольная надо покатать
#
# mcla en senna. суперкар за $ . . можно по городу гонять. производство начнется в следующем году и всего будет…
#
# час кода. 👌🤘
#
# шоураннером ведьмака на ne flix станет лорен шмидт. она уже делала сорвиголову например. только бы не пролюбили т…
#
# турбо киа на сил. предлагают покататься на такой. а я только за. ✌️
#
#  hese s ick n s les a e wa e p f an cu p f p ec y u fee n h li ay.
#
# спилберг создаст очередную франшизу которую будет доить ближайшие лет. или не создаст.
#
#
#  досрочная утечка samsung galaxy a + попал на видео
#
# y u ube объявляет крестовый поход против детского контента. блокирует самый популярный у нас канал vla c azysh w.…
#
#  домашнее аудио это сложно а так что то от b&amp w или b&amp вполне затащит
#
# а шо там pubg на xb x выходит так может и изучу чо за хреновина.
#
#
#  леон
#
#  это спортивный интерес
#
#  ага
#
#  когда мне понадобится твое мнение… кого я обманываю мне не интересно твое мнение. 🤦‍♂️
#
# могли бы янгу и красную дать и пенальти на силве назначить но я итак в плюсе.
#
#  очень скрытая
#
# лицом отбить это уровень.
#
# в первом тайме манчестерские мужчины меня порадовали теперь во втором тайме уолкер получает в своей штрафной вторую желтую и дело сделано.
#
#  это даже не слова лебедева об этом давно говорят
#
#  так я тут
#
#  типа того
#
#  самое время перестать мне писать всякую херню
#
# самое время посмотреть новости. 🤘
#
#
#
#
# я тут доспех за кристаллов продал так что в любом случае в плюсе.
#
# где время для россии идоры
#
#  статистика это грустно
#
# сегодня в игре наши любимые ставочки.
#
# вот так в ливерпуле надо было.
#
#  так то продается миллионами
#
#  ээ в смысле
#
#  да мы с ним это обсуждали в токио 👌
#
# не знаю. «монобровь» iph ne x это его отличительная черта. раньше была кнопка а теперь так. смотришь на все эти см…
#
# какой хороший сегодня день.
#
# что то человек паук на ps будет лютейшим походу.
#
#
# 😂😂😂
#
#  это походу просто глюк статы сошиалблейда
#
#  вообще кстати не играю в этот режим
#
#  ну если ты в итоге тихонечко спишь то норм. а если ужрался в слюни и ведешь себя как мудак то мраз…
#
#  конечно короной закинулся и телепортировался в ла.
#
#  дядю валю напомнило
#
#
#  типа того во первых крепче ничего нет а во вторых чтоб уснуть
#
#  да надо дебилов организовать
#
# интересно а бывает что то еще более вечное чем пробка около крокуса на мкад надо наверное еще плиточки навернут…
#
# хочу купить рекламу у мораны баттори.
#
#  так это давно было
#
#  ночами
#
#  не это мы просто играли

# %%
public_tweets = api.home_timeline()
for tweet in user.timeline(count=5):
    print tweet.text + "\n"
# Out:
# RT @AppleExplosion: Почему iPhone Xc будет крут? Доступная версия iPhone X в ярких цветах!
# https://t.co/gFPIHfINEI
# Как может выглядеть бюд…
#
# Фото для тех, кто считает, что Порще не идет зеленый. https://t.co/OLHo8bug2i
#
# Очень. :) https://t.co/srrkk2JBXF
#
# @LekxT Без шумодава
#
# RT @de_creador13: Страдаю с @wylsacom https://t.co/a4sLuVVG7k
